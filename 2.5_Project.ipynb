# %% [markdown]
# ![Data Science Black@300x.png](https://i.imgur.com/KIHm5UF.png)
#
# # Proyecto
#
# **Descripcion:** Consulta de Yahoo API a valores de la bolsa y procesarlo con la libreria de Python
#
# ¿Tienes un dataset y quieres sacarle partido? ¿Necesitas analizar los datos de un archivo .csv? Pandas es una librería de Python con multitud de métodos y funcionalidades que te permitirán desgranar y agrupar la información que esconden esos datos para tomar decisiones.
#
# En este post te presento los primeros pasos para poder manejarte con la librería Pandas de Python. En próximos artículos, te muestro cómo trabajar con los datos de DataFrames, visualizaciones, etc. Pero para comenzar, ¡unos pasos básicos!

# %% [markdown]
# # DataFrame vs. Series
#
# Dos términos técnicos muy útiles para hacerte con el vocabulario de pandas son DataFrame y Serie. La tabla que almacena los datos no se llama tabla, si no DataFrame y las columnas, se denominan Series.

# %% [markdown]
# ![image1](https://pbpython.com/images/pandas_dtypes.png)
#
# ![image2](https://miro.medium.com/max/1400/1*4TlRz6qT-TFKm9etPbAu3w.png)

# %% [markdown]
# # Importa pandas
#
# Para comenzar, necesitas tener instalado algunas de las librerías (en Terminal: pip3 install y el nombre de la librería), que se importan al inicio del documento .ipynb / .py. Puedes darle un alias para que al hacer uso de ellas sea más cómodo llamarlas. Por convención, a pandas se le da el alias “pd”.

# %%
# !pip install pandas yfinance matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (1.5.0)
# Requirement already satisfied: yfinance in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (0.1.74)
# Collecting matplotlib
#   Downloading matplotlib-3.6.0-cp310-cp310-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.23.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: requests>=2.26 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.3/55.3 kB 1.5 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.5-cp310-cp310-win_amd64.whl (164 kB)
#      -------------------------------------- 164.1/164.1 kB 9.6 MB/s eta 0:00:00
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp310-cp310-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 69.5 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.37.3-py3-none-any.whl (959 kB)
#      ------------------------------------- 960.0/960.0 kB 30.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\faustino_aguilar\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.5 cycler-0.11.0 fonttools-4.37.3 kiwisolver-1.4.4 matplotlib-3.6.0 pillow-9.2.0

# %%
import pandas as pd

# %% [markdown]
# La librería pandas es una herramienta desarrollada sobre Python, muy útil y flexible para análisis de datos, ya que partiendo de un dataset te permite generar un DataFrame y analizarlo gracias a diferentes métodos.

# %%
import yfinance as yf
msft = yf.Ticker("MSFT")
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 221000,
#  'longBusinessSummary': 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. The company operates in three segments: Productivity and Business Processes, Intelligent Cloud, and More Personal Computing. The Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, Microsoft Viva, and Skype for Business; Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. The Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related Client Access Licenses; GitHub that provides a collaboration platform and code hosting service for developers; Nuance provides healthcare and enterprise AI solutions; and Azure, a cloud platform. It also offers enterprise support, Microsoft consulting, and nuance professional services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification on Microsoft products. The More Personal Computing segment provides Windows original equipment manufacturer (OEM) licensing and other non-volume licensing of the Windows operating system; Windows Commercial, such as volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; and Windows Internet of Things. It also offers Surface, PC accessories, PCs, tablets, gaming and entertainment consoles, and other devices; Gaming, including Xbox hardware, and Xbox content and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online stores, and retail stores. Microsoft Corporation was founded in 1975 and is headquartered in Redmond, Washington.',
#  'city': 'Redmond',
#  'phone': '425 882 8080',
#  'state': 'WA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://www.microsoft.com',
#  'maxAge': 1,
#  'address1': 'One Microsoft Way',
#  'fax': '425 706 7329',
#  'industry': 'Software—Infrastructure',
#  'ebitdaMargins': 0.49418998,
#  'profitMargins': 0.36686,
#  'grossMargins': 0.68402,
#  'operatingCashflow': 89034997760,
#  'revenueGrowth': 0.124,
#  'operatingMargins': 0.42055,
#  'ebitda': 97982996480,
#  'targetLowPrice': 275,
#  'recommendationKey': 'buy',
#  'grossProfits': 135620000000,
#  'freeCashflow': 49479000064,
#  'targetMedianPrice': 330,
#  'currentPrice': 239.78,
#  'earningsGrowth': 0.031,
#  'currentRatio': 1.785,
#  'returnOnAssets': 0.14919,
#  'numberOfAnalystOpinions': 43,
#  'targetMeanPrice': 333.24,
#  'debtToEquity': 47.075,
#  'returnOnEquity': 0.47151002,
#  'targetHighPrice': 411,
#  'totalCash': 104748998656,
#  'totalDebt': 78399995904,
#  'totalRevenue': 198269992960,
#  'totalCashPerShare': 14.045,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 26.45,
#  'quickRatio': 1.567,
#  'recommendationMean': 1.7,
#  'exchange': 'NMS',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'messageBoardId': 'finmb_21835',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 8.816,
#  'beta3Year': None,
#  'enterpriseToEbitda': 17.84,
#  '52WeekChange': -0.16757041,
#  'morningStarRiskRating': None,
#  'forwardEps': 11.94,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 7457889792,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 22.313,
#  'sharesShort': 40544332,
#  'sharesPercentSharesOut': 0.0054,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1656547200,
#  'heldPercentInstitutions': 0.72065,
#  'netIncomeToCommon': 72737996800,
#  'trailingEps': 9.65,
#  'lastDividendValue': 0.62,
#  'SandP52WeekChange': -0.16336197,
#  'priceToBook': 10.7462015,
#  'heldPercentInsiders': 0.00079,
#  'nextFiscalYearEnd': 1719705600,
#  'yield': None,
#  'mostRecentQuarter': 1656547200,
#  'shortRatio': 1.95,
#  'sharesShortPreviousMonthDate': 1659052800,
#  'floatShares': 7451179769,
#  'beta': 0.942868,
#  'enterpriseValue': 1748032684032,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1045526400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1660694400,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.017,
#  'priceToSalesTrailing12Months': 9.019281,
#  'dateShortInterest': 1661904000,
#  'pegRatio': 1.52,
#  'ytdReturn': None,
#  'forwardPE': 20.082077,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0054,
#  'sharesShortPriorMonth': 38192351,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 236.41,
#  'regularMarketOpen': 236.81,
#  'twoHundredDayAverage': 283.3882,
#  'trailingAnnualDividendYield': 0.01049025,
#  'payoutRatio': 0.2508,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 241.06,
#  'navPrice': None,
#  'averageDailyVolume10Day': 29721210,
#  'regularMarketPreviousClose': 236.41,
#  'fiftyDayAverage': 266.5408,
#  'trailingAnnualDividendRate': 2.48,
#  'open': 236.81,
#  'toCurrency': None,
#  'averageVolume10days': 29721210,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 2.72,
#  'exDividendDate': 1668556800,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 234.731,
#  'currency': 'USD',
#  'trailingPE': 24.84767,
#  'regularMarketVolume': 14764470,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1788252782592,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 24557582,
#  'dayLow': 234.731,
#  'ask': 240.3,
#  'askSize': 2900,
#  'volume': 14764470,
#  'fiftyTwoWeekHigh': 349.67,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.21,
#  'fiftyTwoWeekLow': 234.5,
#  'bid': 240.25,
#  'tradeable': False,
#  'dividendYield': 0.0114,
#  'bidSize': 1200,
#  'dayHigh': 241.06,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 239.78,
#  'preMarketPrice': 236.4,
#  'logo_url': 'https://logo.clearbit.com/microsoft.com',
#  'trailingPegRatio': 1.7888}

# %% [markdown]
# # Descripcion del proyecto
#
# Vamos utilizar Python para descargar datos financieros de bases de datos gratuitas en línea, manipular los datos descargados y luego crear algunos indicadores técnicos básicos que luego se utilizarán como base de nuestra estrategia cuantitativa. Para ello, vamos a utilizar uno de los paquetes de Python más potentes y utilizados para la manipulación de datos, pandas.
#
#
# Utilizando como referencia la documentaciones oficiales:
#
# Pandas: https://pandas.pydata.org/docs/getting_started/intro_tutorials/01_table_oriented.html
# NumPy: https://numpy.org/doc/stable/user/absolute_beginners.html
#
#
# Preguntas:
#
# 1. Cual es el crecimiento revenueGrowth ?
# 2. Cual es la ganancia neta grossProfits?
# 3. Cual es

# %%
import pandas as pd
import requests
import numpy as np

ticker = "AAPL"


def getdata(url):
  r = requests.get(url,headers ={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
  data = pd.read_html(r.text)
  return data

summary_url = f'https://finance.yahoo.com/quote/{ticker}?p={ticker}'
summary_data = getdata(summary_url)


data = [summary_data[0], summary_data[1]]
data = pd.concat(summary_data)
data.reset_index(drop=True, inplace=True)

df = data.transpose()
df.columns = df.iloc[0]
df = df.drop(0)
df = df.reset_index(drop=True)

historiscal_url= f'https://finance.yahoo.com/quote/{ticker}/history?p={ticker}'
historiscal_data = getdata(historiscal_url)
data = historiscal_data[0]

data = data.iloc[:-1 , :]

data = data[data["Open"].str.contains("Dividend") == False]

print(data)
# Out:
#             Date    Open    High     Low  Close* Adj Close**     Volume
# 0   Oct 26, 2022  150.96  151.99  148.04  148.69      148.69   63247891
# 1   Oct 25, 2022  150.09  152.49  149.36  152.34      152.34   74373600
# 2   Oct 24, 2022  147.19  150.23  146.00  149.45      149.45   75981900
# 3   Oct 21, 2022  142.87  147.85  142.65  147.27      147.27   86464700
# 4   Oct 20, 2022  143.02  145.89  142.65  143.39      143.39   64522000
# ..           ...     ...     ...     ...     ...         ...        ...
# 95  Jun 13, 2022  132.87  135.20  131.44  131.88      131.70  122207100
# 96  Jun 10, 2022  140.28  140.76  137.06  137.13      136.94   91437900
# 97  Jun 09, 2022  147.08  147.95  142.53  142.64      142.44   69473000
# 98  Jun 08, 2022  148.58  149.87  147.46  147.96      147.75   53950200
# 99  Jun 07, 2022  144.35  149.00  144.10  148.71      148.50   67808200
#
# [99 rows x 7 columns]

# %%
import pandas as pd
import requests
import numpy as np

ticker = "MSFT"
